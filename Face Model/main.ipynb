# %% [markdown]
# <h1 style="color:skyblue;text-align:center;">Face Recognition Model Using FaceNet,MTCNN,SVM</h1>

# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from mtcnn import MTCNN
from keras_facenet import FaceNet
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import pickle
import logging

# %%
# Set up logging
logging.basicConfig(level=logging.INFO)

# %%
class FACELOADING:
    def __init__(self, directory):
        self.directory = directory
        self.target_size = (160, 160)
        self.X = []
        self.Y = []
        self.detector = MTCNN()
    
    def extract_faces(self, filename):
        img = cv2.imread(filename)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        try:
            x, y, w, h = self.detector.detect_faces(img)[0]['box']
            x, y = abs(x), abs(y)
            face = img[y:y+h, x:x+w]
            face_arr = cv2.resize(face, self.target_size)
            return face_arr
        except Exception as e:
            logging.error(f"Face detection failed for {filename}: {e}")
            return None

    def load_faces(self, dir):
        FACES = []
        for im_name in os.listdir(dir):
            path = os.path.join(dir, im_name)
            single_face = self.extract_faces(path)
            if single_face is not None:
                FACES.append(single_face)
        return FACES
    
    def load_classes(self):
        for sub_dir in os.listdir(self.directory):
            path = os.path.join(self.directory, sub_dir)
            FACES = self.load_faces(path)
            labels = [sub_dir for _ in range(len(FACES))]
            logging.info(f"Loaded {len(labels)} faces for class {sub_dir}")
            self.X.extend(FACES)
            self.Y.extend(labels)
        return np.asarray(self.X), np.asarray(self.Y)

    def plot_all_images(self):
        if not self.X:
            self.load_classes()
        
        num_images = len(self.X)
        cols = 5 
        rows = num_images // cols if num_images % cols == 0 else num_images // cols + 1
        
        fig, ax = plt.subplots(rows, cols, figsize=(15, 15))
        ax = ax.ravel()  
        
        for i in range(num_images):
            ax[i].imshow(self.X[i])
            ax[i].set_title(self.Y[i])
            ax[i].axis('off')  
            
        for i in range(num_images, rows * cols):
            ax[i].axis('off')
        
        plt.tight_layout()
        plt.show()

# %%
# Initialize FACELOADING and load dataset
faceloading = FACELOADING(r"C:\Users\boddu\Desktop\Domain Project\Face Recognition\dataset")
X, Y = faceloading.load_classes()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# ...

# %%
# Embedding using FaceNet
embedder = FaceNet()

def get_embedding(face_img):
    face_img = face_img.astype('float32')
    face_img = np.expand_dims(face_img, axis=0)
    yhat = embedder.embeddings(face_img)
    return yhat[0]
# Out:
# INFO:keras_facenet.embedding_model:Loading weights.
# INFO:keras_facenet.utils:Looking for C:\Users\boddu/.keras-facenet\20180402-114759\20180402-114759-weights.h5
# WARNING:tensorflow:From c:\Users\boddu\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:From c:\Users\boddu\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
EMBEDDED_X = np.asarray([get_embedding(img) for img in X])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# ...

# %%
# Save the embeddings
np.savez_compressed('faces_embeddings.npz', EMBEDDED_X, Y)

# %%
# Encode labels
encoder = LabelEncoder()
encoder.fit(Y)
Y_encoded = encoder.transform(Y)

# %%
# Split data into training and test sets
X_train, X_test, Y_train, Y_test = train_test_split(EMBEDDED_X, Y_encoded, shuffle=True, random_state=17)

# %%
# SVM model with GridSearchCV for hyperparameter tuning
param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']
}

# %%
svc = SVC(probability=True)
model = GridSearchCV(svc, param_grid, cv=5, scoring='accuracy', verbose=2)
model.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.0s
# ...

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score

print("Train Accuracy:", accuracy_score(Y_train, model.predict(X_train)) * 100 ,"%")
print("Test Accuracy:", accuracy_score(Y_test, model.predict(X_test)) * 100 ,"%")
# Out:
# Train Accuracy: 100.0 %
# Test Accuracy: 96.93877551020408 %

# %%
# Save the model and the label encoder together
with open('svm_model_with_encoder.pkl', 'wb') as f:
    pickle.dump({'model': model, 'encoder': encoder}, f)

# %% [markdown]
# <h1 style="color:skyblue;text-align:center">Predection</h1>

# %%
# Test on a new image
test_im_path = r"C:\Users\boddu\Desktop\Domain Project\Face Recognition\dataset\v Lakshmi\frame00006.jpg"
t_im = cv2.imread(test_im_path)
t_im = cv2.cvtColor(t_im, cv2.COLOR_BGR2RGB)
x, y, w, h = faceloading.detector.detect_faces(t_im)[0]['box']
t_im = t_im[y:y+h, x:x+w]
t_im = cv2.resize(t_im, (160, 160))

# Get embedding and predict
test_im_embedding = get_embedding(t_im)
test_im_embedding = np.expand_dims(test_im_embedding, axis=0)
ypreds = model.predict(test_im_embedding)

# Get predicted label
predicted_label = encoder.inverse_transform(ypreds)
print(f"Predicted label: {predicted_label[0]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Predicted label: V Lakshmi
